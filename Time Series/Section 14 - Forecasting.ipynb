# %% [markdown]
# ## Packages

# %%
import numpy as np
import pandas as pd
import scipy
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import statsmodels.graphics.tsaplots as sgt
import statsmodels.tsa.stattools as sts
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from pmdarima.arima import auto_arima
from arch import arch_model
import yfinance
import warnings
warnings.filterwarnings("ignore")
sns.set()

# %% [markdown]
# ## Loading the data

# %%
raw_data = yfinance.download (tickers = "^GSPC ^FTSE ^N225 ^GDAXI", start = "1994-01-07", 
                              end = "2019-09-01", interval = "1d", group_by = 'ticker', auto_adjust = True, treads = True)
# Out:
# [*********************100%***********************]  4 of 4 completed

# %%
df_comp = raw_data.copy()

# %%
df_comp['spx'] = df_comp['^GSPC'].Close[:]
df_comp['dax'] = df_comp['^GDAXI'].Close[:]
df_comp['ftse'] = df_comp['^FTSE'].Close[:]
df_comp['nikkei'] = df_comp['^N225'].Close[:]

# %%
df_comp = df_comp.iloc[1:]
del df_comp['^N225']
del df_comp['^GSPC']
del df_comp['^GDAXI']
del df_comp['^FTSE']
df_comp=df_comp.asfreq('b')
df_comp=df_comp.fillna(method='ffill')

# %% [markdown]
# ## Creating Returns

# %%
df_comp['ret_spx'] = df_comp.spx.pct_change(1).mul(100)
df_comp['ret_ftse'] = df_comp.ftse.pct_change(1).mul(100)
df_comp['ret_dax'] = df_comp.dax.pct_change(1).mul(100)
df_comp['ret_nikkei'] = df_comp.nikkei.pct_change(1).mul(100)

# %%
df_comp['norm_ret_spx'] = df_comp.ret_spx.div(df_comp.ret_spx[1])*100
df_comp['norm_ret_ftse'] = df_comp.ret_ftse.div(df_comp.ret_ftse[1])*100
df_comp['norm_ret_dax'] = df_comp.ret_dax.div(df_comp.ret_dax[1])*100
df_comp['norm_ret_nikkei'] = df_comp.ret_nikkei.div(df_comp.ret_nikkei[1])*100

# %% [markdown]
# ## Splitting the Data

# %%
size = int(len(df_comp)*0.8)
df, df_test = df_comp.iloc[:size], df_comp.iloc[size:]

# %% [markdown]
# ## Fitting a Model

# %%
model_ar = ARIMA(df.ftse, order = (1,0,0))
results_ar = model_ar.fit()

# %% [markdown]
# ## Simple Forecasting

# %%
df.tail()
# Out:
#                     spx          dax         ftse        nikkei   ret_spx  \
#
# Date
# 2014-07-08  1963.709961  9772.669922  6738.500000  15314.410156 -0.704880
# 2014-07-09  1972.829956  9808.200195  6718.000000  15302.650391  0.464427
# 2014-07-10  1964.680054  9659.129883  6672.399902  15216.469727 -0.413107
# 2014-07-11  1967.569946  9666.339844  6690.200195  15164.040039  0.147092
# 2014-07-14  1977.099976  9783.009766  6746.100098  15296.820312  0.484355
#
#             ret_ftse   ret_dax ret_nikkei norm_ret_spx norm_ret_ftse  \
#
# Date
# 2014-07-08 -1.245695 -1.346653  -0.422839   -61.680354    794.952349
# 2014-07-09 -0.304222  0.363568  -0.076789    40.639543    194.142222
# 2014-07-10 -0.678775 -1.519854  -0.563175   -36.148835    433.166778
# 2014-07-11  0.266775  0.074644  -0.344559    12.871270   -170.245033
# 2014-07-14  0.835549  1.206971   0.875626    42.383382   -533.213704
#
#             norm_ret_dax norm_ret_nikkei
#
# Date
# 2014-07-08 -59866.246313      -23.991315
# 2014-07-09  16162.615912       -4.356898
# 2014-07-10 -67565.994483      -31.953776
# 2014-07-11   3318.342727      -19.549802
# 2014-07-14  53656.603796       49.681837

# %%
# create variables that will help us change the periods easily instead of typing them up every time
# make sure the start and end dates are business days, otherwise the code will result in an error
start_date = "2014-07-15"
end_date = "2015-01-01"

# %%
end_date = "2019-10-23"
df_pred = results_ar.predict(start = start_date, end = end_date)

# %%
df_pred[start_date:end_date].plot(figsize=(20,5), color = "red")
df_test.ftse[start_date:end_date].plot(color="blue")
plt.title("Prediction vs Actual", size=22)
plt.show()

# %% [markdown]
# ### Using Returns Instead

# %%
end_date = "2015-01-01"

model_ret_ar = ARIMA(df.ret_ftse[1:], order=(1,0,0))
results_ret_ar = model_ret_ar.fit()

df_pred_ret_ar = results_ret_ar.predict(start=start_date, end=end_date)

# %%
df_pred_ret_ar[start_date:end_date].plot(figsize=(20,5), color = "red")
df_test.ret_ftse[start_date:end_date].plot(color="blue")
plt.title("Prediction vs Actual (Returns)", size=22)
plt.show()

# %%
results_ret_ar.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               ARMA Model Results
# ==============================================================================
# Dep. Variable:               ret_ftse   No. Observations:                 5351
# Model:                     ARMA(1, 0)   Log Likelihood               -8343.621
# Method:                       css-mle   S.D. of innovations              1.151
# Date:                Thu, 24 Mar 2022   AIC                          16693.241
# Time:                        11:34:09   BIC                          16712.996
# Sample:                    01-10-1994   HQIC                         16700.141
#                          - 07-14-2014
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.0192      0.015      1.246      0.213      -0.011       0.049
# ar.L1.ret_ftse    -0.0223      0.014     -1.634      0.102      -0.049       0.004
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1          -44.7719           +0.0000j           44.7719            0.5000
# -----------------------------------------------------------------------------
# """

# %% [markdown]
# ### MA

# %%
end_date = "2015-01-01"

model_ret_ma = ARIMA(df.ret_ftse[1:], order=(0,0,1))
results_ret_ma = model_ret_ma.fit()

df_pred_ret_ma = results_ret_ma.predict(start=start_date, end=end_date)

df_pred_ret_ma[start_date:end_date].plot(figsize=(20,5), color = "red")
df_test.ret_ftse[start_date:end_date].plot(color="blue")
plt.title("Prediction vs Actual (Returns) - MA", size=22)
plt.show()

# %%
df_pred_ret_ma.head()
# Out:
# 2014-07-15   -0.001258
# 2014-07-16    0.019178
# 2014-07-17    0.019178
# 2014-07-18    0.019178
# 2014-07-21    0.019178
# Freq: B, dtype: float64

# %% [markdown]
# ### ARMA

# %%
model_ret_arma = ARIMA(df.ret_ftse[1:], order=(1,0,1))
results_ret_arma = model_ret_arma.fit()

df_pred_ret_arma = results_ret_arma.predict(start=start_date, end=end_date)

df_pred_ret_arma[start_date:end_date].plot(figsize=(20,5), color = "red")
df_test.ret_ftse[start_date:end_date].plot(color="blue")
plt.title("Prediction vs Actual (Returns) - ARMA", size=22)
plt.show()

# %%
df_pred_ret_arma.head()
# Out:
# 2014-07-15    0.027396
# 2014-07-16    0.025564
# 2014-07-17    0.024142
# 2014-07-18    0.023039
# 2014-07-21    0.022183
# Freq: B, dtype: float64

# %%
df_pred_ret_arma.tail()
# Out:
# 2014-12-26    0.019221
# 2014-12-29    0.019221
# 2014-12-30    0.019221
# 2014-12-31    0.019221
# 2015-01-01    0.019221
# Freq: B, dtype: float64

# %%
model_ret_arma613 = ARIMA(df.ret_ftse[1:], order=(6,1,3))
results_ret_arma613 = model_ret_arma613.fit()

df_pred_ret_arma613 = results_ret_arma613.predict(start=start_date, end=end_date)

df_pred_ret_arma613[start_date:end_date].plot(figsize=(20,5), color = "red")
df_test.ret_ftse[start_date:end_date].plot(color="blue")
plt.title("Prediction vs Actual (Returns) - ARMA(6,1,3)", size=22)
plt.show()

# %% [markdown]
# ### ARMAX

# %%
model_ret_armax = ARIMA(df.ret_ftse[1:], exog = df[["ret_spx","ret_dax","ret_nikkei"]][1:], order=(1,0,1))
results_ret_armax = model_ret_armax.fit()

df_pred_armax = results_ret_armax.predict(start=start_date, end=end_date, exog=df_test[["ret_spx","ret_dax","ret_nikkei"]][start_date:end_date])

df_pred_armax[start_date:end_date].plot(figsize=(20,5), color="red")
df_test.ret_ftse[start_date:end_date].plot(color="blue")
plt.title("Prediction vs Actual (Returns) - ARMAX(1,0,1)", size=22)
plt.show()

# %% [markdown]
# ### SARMA

# %%
end_date = "2015-01-01"
model_ret_sarma = SARIMAX(df.ret_ftse[1:], order=(3,0,4), seasonal_order=(3,0,2,5))
results_ret_sarma = model_ret_sarma.fit()

df_ret_sarma = results_ret_sarma.predict(start =start_date, end = end_date)

df_ret_sarma[start_date:end_date].plot(figsize=(20,5), color="red")
df_test.ret_ftse[start_date:end_date].plot(color="blue")
plt.title("Predictions vs Actual (SARMA)", size=22)
plt.show()

# %% [markdown]
# ### SARIMAX

# %%
model_ret_sarimax = SARIMAX(df.ret_ftse[1:], exog=df[["ret_spx","ret_dax","ret_nikkei"]][1:], order=(3,0,4), seazonal_order=(3,0,2,5))

results_ret_sarimax = model_ret_sarimax.fit()

df_pred_sarimax = results_ret_sarimax.predict(start=start_date, end=end_date, exog=df_test[["ret_spx","ret_dax","ret_nikkei"]][start_date:end_date])

df_pred_sarimax[start_date:end_date].plot(figsize=(20,5), color="red")
df_test.ret_ftse[start_date:end_date].plot(color="blue")
plt.title("Predictions vs Actual - SARIMAX", size=22)
plt.show()

# %% [markdown]
# ### Auto ARIMA

# %%
model_auto = auto_arima(df.ret_ftse[1:], exogenous = df[["ret_spx","ret_dax","ret_nikkei"]][1:], 
                       m=5, max_p=5, max_q=5, max_P=5, max_Q=5)

# %%
df_auto_pred = pd.DataFrame(model_auto.predict(n_periods=len(df_test[start_date:end_date]), 
                            exogenous=df_test[["ret_spx","ret_dax","ret_nikkei"]][start_date:end_date]),
                            index=df_test[start_date:end_date].index)

# %%
df_auto_pred.plot(figsize=(20,5), color="red")
df_test.ret_ftse[start_date:end_date].plot(color="blue")
plt.title("Auto Model Predictions vs Real Data", size=22)
plt.show()

# %% [markdown]
# ### Comparing All the Models (Returns)

# %%
end_date = "2015-01-01"
df_pred_ret_ar[start_date:end_date].plot(figsize=(20,10), color="yellow")
df_pred_ret_ma[start_date:end_date].plot(color="pink")
df_pred_ret_arma[start_date:end_date].plot(color="cyan")
df_pred_armax[start_date:end_date].plot(color="green")
df_ret_sarma[start_date:end_date].plot(color="magenta")
df_pred_sarimax[start_date:end_date].plot(color="red")
df_test.ret_ftse[start_date:end_date].plot(color="blue")
plt.legend(['AR', 'MA', 'ARMA', 'ARMAX', 'SARMA', 'SARIMAX'])
plt.title("All models", size=22)
plt.show()

# %% [markdown]
# ### Forecasting Volatility

# %%
mod_garch = arch_model(df_comp.ret_ftse[1:], vol="GARCH", p = 1, q = 1, mean="constant", dist="Normal")
res_garch = mod_garch.fit(last_obs = start_date, update_freq = 10)
# Out:
# Iteration:     10,   Func. Count:     65,   Neg. LLF: 7310.521532726298
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 7310.521523672145
#             Iterations: 12
#             Function evaluations: 74
#             Gradient evaluations: 12

# %%
pred_garch = res_garch.forecast(horizon=1, align='target')

# %%
pred_garch.residual_variance[start_date:].plot(figsize=(20,5), color="red")
df_test.ret_ftse.abs().plot(color="blue", zorder=1)
plt.title("Volatility Predictions", size=22)
plt.show()

# %%
pred_garch = res_garch.forecast(horizon=100, align='target')
pred_garch.residual_variance[-1:]
# Out:
#                h.001     h.002     h.003     h.004     h.005     h.006  \
# Date
# 2019-08-30  0.811058  0.805213  0.867109  0.940863  1.021424  1.086055
#
#                h.007     h.008     h.009     h.010  ...     h.091     h.092  \
# Date                                                ...
# 2019-08-30  1.075133  1.068943  1.082501  1.092079  ...  0.842724  0.844328
#
#                h.093     h.094     h.095     h.096    h.097     h.098  \
# Date
# 2019-08-30  0.835815  0.821136  0.832658  0.844767  0.85596  0.869334
#
#                h.099     h.100
# Date
# 2019-08-30  0.876818  0.891131
#
# [1 rows x 100 columns]

# %% [markdown]
# ### Multvariate Regression Model

# %%
from statsmodels.tsa.api import VAR

# %%
df_ret = df[['ret_spx', 'ret_dax', 'ret_ftse', 'ret_nikkei']][1:]

# %%
model_var_ret = VAR(df_ret)
model_var_ret.select_order(20)
results_var_ret = model_var_ret.fit(ic = 'aic')

# %%
results_var_ret.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Thu, 24, Mar, 2022
# Time:                     14:30:56
# --------------------------------------------------------------------
# No. of Equations:         4.00000    BIC:                   0.329002
# Nobs:                     5346.00    HQIC:                  0.261684
# Log likelihood:          -30861.5    FPE:                    1.25301
# AIC:                     0.225548    Det(Omega_mle):         1.23351
# --------------------------------------------------------------------
# Results for equation ret_spx
# ================================================================================
#                    coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------
# const                 0.039217         0.016160            2.427           0.015
# L1.ret_spx           -0.110842         0.017560           -6.312           0.000
# L1.ret_dax            0.064906         0.019025            3.412           0.001
# L1.ret_ftse          -0.012983         0.024445           -0.531           0.595
# L1.ret_nikkei        -0.014782         0.012712           -1.163           0.245
# L2.ret_spx           -0.043340         0.020259           -2.139           0.032
# L2.ret_dax            0.022406         0.019229            1.165           0.244
# L2.ret_ftse          -0.037052         0.024844           -1.491           0.136
# L2.ret_nikkei        -0.014083         0.012852           -1.096           0.273
# L3.ret_spx           -0.003097         0.020531           -0.151           0.880
# L3.ret_dax           -0.011760         0.019251           -0.611           0.541
# L3.ret_ftse           0.012537         0.024747            0.507           0.612
# L3.ret_nikkei         0.010753         0.012853            0.837           0.403
# L4.ret_spx           -0.045871         0.020413           -2.247           0.025
# L4.ret_dax           -0.005391         0.019231           -0.280           0.779
# L4.ret_ftse           0.058614         0.024698            2.373           0.018
# L4.ret_nikkei        -0.006096         0.012835           -0.475           0.635
# L5.ret_spx           -0.035094         0.019211           -1.827           0.068
# L5.ret_dax            0.011908         0.019108            0.623           0.533
# L5.ret_ftse          -0.048022         0.023745           -2.022           0.043
# L5.ret_nikkei         0.003039         0.011499            0.264           0.792
# ================================================================================
#
# Results for equation ret_dax
# ================================================================================
#                    coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------
# const                 0.030974         0.019443            1.593           0.111
# L1.ret_spx            0.414664         0.021128           19.627           0.000
# L1.ret_dax           -0.121294         0.022890           -5.299           0.000
# L1.ret_ftse          -0.153570         0.029411           -5.221           0.000
# L1.ret_nikkei        -0.043067         0.015294           -2.816           0.005
# L2.ret_spx            0.173903         0.024375            7.134           0.000
# L2.ret_dax           -0.054455         0.023135           -2.354           0.019
# L2.ret_ftse          -0.063419         0.029891           -2.122           0.034
# L2.ret_nikkei        -0.029186         0.015463           -1.887           0.059
# L3.ret_spx            0.099698         0.024702            4.036           0.000
# L3.ret_dax           -0.054206         0.023162           -2.340           0.019
# L3.ret_ftse          -0.022453         0.029775           -0.754           0.451
# L3.ret_nikkei         0.012944         0.015464            0.837           0.403
# L4.ret_spx           -0.001189         0.024560           -0.048           0.961
# L4.ret_dax           -0.018521         0.023138           -0.800           0.423
# L4.ret_ftse           0.059153         0.029716            1.991           0.047
# L4.ret_nikkei         0.010962         0.015442            0.710           0.478
# L5.ret_spx           -0.016895         0.023114           -0.731           0.465
# L5.ret_dax            0.030880         0.022990            1.343           0.179
# L5.ret_ftse          -0.111615         0.028569           -3.907           0.000
# L5.ret_nikkei         0.012540         0.013836            0.906           0.365
# ================================================================================
#
# Results for equation ret_ftse
# ================================================================================
#                    coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------
# const                 0.008811         0.014661            0.601           0.548
# L1.ret_spx            0.430195         0.015932           27.002           0.000
# L1.ret_dax           -0.059510         0.017261           -3.448           0.001
# L1.ret_ftse          -0.212413         0.022179           -9.577           0.000
# L1.ret_nikkei        -0.046192         0.011533           -4.005           0.000
# L2.ret_spx            0.160015         0.018381            8.705           0.000
# L2.ret_dax           -0.049151         0.017446           -2.817           0.005
# L2.ret_ftse          -0.081735         0.022541           -3.626           0.000
# L2.ret_nikkei        -0.023352         0.011661           -2.003           0.045
# L3.ret_spx            0.104669         0.018627            5.619           0.000
# L3.ret_dax           -0.034839         0.017466           -1.995           0.046
# L3.ret_ftse          -0.086717         0.022453           -3.862           0.000
# L3.ret_nikkei         0.002899         0.011661            0.249           0.804
# L4.ret_spx            0.018423         0.018520            0.995           0.320
# L4.ret_dax           -0.006171         0.017448           -0.354           0.724
# L4.ret_ftse           0.015636         0.022409            0.698           0.485
# L4.ret_nikkei         0.015264         0.011645            1.311           0.190
# L5.ret_spx            0.010344         0.017430            0.593           0.553
# L5.ret_dax            0.044521         0.017337            2.568           0.010
# L5.ret_ftse          -0.108627         0.021544           -5.042           0.000
# L5.ret_nikkei        -0.012695         0.010433           -1.217           0.224
# ================================================================================
#
# Results for equation ret_nikkei
# ================================================================================
#                    coefficient       std. error           t-stat            prob
# --------------------------------------------------------------------------------
# const                -0.019074         0.017825           -1.070           0.285
# L1.ret_spx            0.434234         0.019370           22.418           0.000
# L1.ret_dax            0.080364         0.020985            3.830           0.000
# L1.ret_ftse           0.149834         0.026964            5.557           0.000
# L1.ret_nikkei        -0.150418         0.014022          -10.728           0.000
# L2.ret_spx            0.078116         0.022347            3.496           0.000
# L2.ret_dax            0.035939         0.021210            1.694           0.090
# L2.ret_ftse          -0.048024         0.027404           -1.752           0.080
# L2.ret_nikkei        -0.039938         0.014176           -2.817           0.005
# L3.ret_spx            0.057511         0.022646            2.540           0.011
# L3.ret_dax            0.000067         0.021234            0.003           0.997
# L3.ret_ftse          -0.015279         0.027297           -0.560           0.576
# L3.ret_nikkei        -0.020292         0.014177           -1.431           0.152
# L4.ret_spx            0.014705         0.022516            0.653           0.514
# L4.ret_dax           -0.019775         0.021212           -0.932           0.351
# L4.ret_ftse           0.047441         0.027243            1.741           0.082
# L4.ret_nikkei        -0.028420         0.014157           -2.007           0.045
# L5.ret_spx           -0.000917         0.021191           -0.043           0.965
# L5.ret_dax            0.035681         0.021077            1.693           0.090
# L5.ret_ftse           0.016427         0.026192            0.627           0.531
# L5.ret_nikkei        -0.008921         0.012684           -0.703           0.482
# ================================================================================
#
# Correlation matrix of residuals
#                ret_spx   ret_dax  ret_ftse  ret_nikkei
# ret_spx       1.000000  0.605314  0.569710    0.151368
# ret_dax       0.605314  1.000000  0.775852    0.202503
# ret_ftse      0.569710  0.775852  1.000000    0.210808
# ret_nikkei    0.151368  0.202503  0.210808    1.000000

# %%
lag_order_ret = results_var_ret.k_ar
var_pred_ret = results_var_ret.forecast(df_ret.values[-lag_order_ret:], len(df_test[start_date:end_date]))
df_ret_pred = pd.DataFrame(data=var_pred_ret, index=df_test[start_date:end_date].index, 
                           columns=df_test[start_date:end_date].columns[4:8])
df_ret_pred.ret_nikkei[start_date:end_date].plot(color="red")
df_test.ret_nikkei[start_date:end_date].plot(color="blue")
plt.title("Nikkei real vs prediction", size=22)
plt.show()

# %%
results_var_ret.plot_forecast(1000)
plt.show()
